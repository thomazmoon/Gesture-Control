# %% [markdown]
# ## Imports

# %%
# These are the misc imports and not required for the modeling process.
# Used to check model score and run time.
from os.path import isfile, join
from os import listdir
import time

# Imports for viewing the images and change
import matplotlib.pyplot as plt
import numpy as np
import cv2

# From Tensorflow
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.applications import InceptionResNetV2 # pretrained model
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense

# %% [markdown]
# ## Making sure we can read in our images

# %%
img_test = load_img('../imgs/train/volume_up/volume_up.56495766-41c0-11ec-8ed5-68545a69f685.jpg')
img_test
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x2294BB46850>

# %%
# Checking shape as well as first list of bgr colors
img_test_2 = cv2.imread('../imgs/train/volume_up/volume_up.56495766-41c0-11ec-8ed5-68545a69f685.jpg')
print(img_test_2.shape)

cv2.imread('../imgs/train/volume_up/volume_up.56495766-41c0-11ec-8ed5-68545a69f685.jpg')[0][:10]
# Out:
# (480, 640, 3)
# array([[255, 255, 254],
#        [255, 255, 254],
#        [255, 255, 254],
#        [255, 255, 254],
#        [255, 255, 254],
#        [255, 255, 254],
#        [255, 255, 254],
#        [255, 255, 254],
#        [255, 255, 254],
#        [255, 255, 254]], dtype=uint8)

# %% [markdown]
# ## Setting up the images in our folders

# %% [markdown]
# #### Make get target names from the folders they were saved in as, and make sure pictures are all the same size

# %%
rescale = ImageDataGenerator(rescale=1/255, # scaling so everything will be from 0 - 1
                             # Next 4 lines will randomly choose images for data augmentation
                             zoom_range = 0.5,
                             horizontal_flip = True,
                             brightness_range = (0.7, 1.3),
                             rotation_range = 20)

train_set = rescale.flow_from_directory('../imgs/train/',
                                    target_size=(480, 640), # just in case any of the pictures changed sizes for some reason
                                    class_mode='categorical',
                                    batch_size=16)

test_set = rescale.flow_from_directory('../imgs/test/',
                                   target_size=(480, 640),
                                   class_mode='categorical',
                                   batch_size= 16)
# Out:
# Found 790 images belonging to 6 classes.
# Found 144 images belonging to 6 classes.

# %% [markdown]
# ## Check out 5 augmented Images

# %%
# Code from Noah Christiansen 
for _ in range(5):
    img, label = train_set.next()
    plt.imshow(img[0])
    plt.show()

# %% [markdown]
# ## Checks

# %%
# Check the class indicies the imageDataGenerator just made
train_set.class_indices
# Out:
# {'forward': 0,
#  'play_pause': 1,
#  'rewind': 2,
#  'screenshot': 3,
#  'volume_down': 4,
#  'volume_up': 5}

# %%
# lets make sure the order and names are the same for both train and test
test_set.class_indices
# Out:
# {'forward': 0,
#  'play_pause': 1,
#  'rewind': 2,
#  'screenshot': 3,
#  'volume_down': 4,
#  'volume_up': 5}

# %%
# Getting the input shape of the image to pass into the model
input_shape = train_set.image_shape
input_shape
# Out:
# (480, 640, 3)

# %% [markdown]
# ## Setting Up `InceptionResNetv2` for Transfer Learning

# %%
base_model = InceptionResNetV2(include_top=False, input_shape = input_shape, pooling='avg')
# Out:
# ...
# 219070464/219055592 [==============================] - 16s 0us/step

# %% [markdown]
# ## Only Training the Final Dense Layer first in order to not change too much of the orignal weights

# %%
base_model.trainable = False
model = Sequential()
model.add(base_model)
model.add(Dense(6, activation = 'softmax'))

model.compile(optimizer=Adam(learning_rate=0.0001),loss='categorical_crossentropy',metrics=['acc'])


step_size_train=train_set.n//train_set.batch_size
step_size_test=test_set.n//test_set.batch_size

# Start timer
t0 = time.time()

# fit the model
history = model.fit(train_set,
                    epochs = 10,
                    verbose = 1,
                    steps_per_epoch = step_size_train,
                    validation_steps = step_size_test,
                    validation_data = test_set)

# lets see how long this takes to run
print(f'{time.time() - t0} seconds to run')
# Out:
# Epoch 1/10
# 49/49 [==============================] - 592s 12s/step - loss: 1.8026 - acc: 0.2145 - val_loss: 1.7882 - val_acc: 0.2014
# Epoch 2/10
# 49/49 [==============================] - 588s 12s/step - loss: 1.7589 - acc: 0.2261 - val_loss: 1.7346 - val_acc: 0.3958
# Epoch 3/10
# 49/49 [==============================] - 578s 12s/step - loss: 1.7070 - acc: 0.3437 - val_loss: 1.6843 - val_acc: 0.3958
# Epoch 4/10
# 49/49 [==============================] - 583s 12s/step - loss: 1.6661 - acc: 0.4264 - val_loss: 1.6470 - val_acc: 0.4792
# Epoch 5/10
# 49/49 [==============================] - 602s 12s/step - loss: 1.6211 - acc: 0.4793 - val_loss: 1.6092 - val_acc: 0.5417
# Epoch 6/10
# 49/49 [==============================] - 581s 12s/step - loss: 1.5825 - acc: 0.5840 - val_loss: 1.5658 - val_acc: 0.6389
# Epoch 7/10
# 49/49 [==============================] - 571s 12s/step - loss: 1.5409 - acc: 0.6008 - val_loss: 1.5175 - val_acc: 0.6667
# Epoch 8/10
# ...

# %% [markdown]
# ## Setting all layers to trainable

# %%
for layer in model.layers: 
    layer.trainable = True

# %%
model.compile(optimizer=Adam(learning_rate=0.0001),loss='categorical_crossentropy',metrics=['acc'])

# Start timer
t0 = time.time()

# lets check the time for this too
history = model.fit(train_set, epochs=10, verbose=1, validation_data=test_set, steps_per_epoch=STEP_SIZE_TRAIN, validation_steps=STEP_SIZE_VALID,
                    callbacks=[ModelCheckpoint('../models/resnet_large.h5', monitor='val_loss', verbose=1, save_best_only=True, mode='auto')])

# lets see how long this takes to run
print(f'{time.time() - t0} seconds to run')
# Out:
# Epoch 1/10
# 49/49 [==============================] - 2212s 45s/step - loss: 0.3153 - acc: 0.9457 - val_loss: 0.2210 - val_acc: 0.9444
#
# Epoch 00001: val_loss improved from inf to 0.22100, saving model to ../models\resnet_large.h5
# Epoch 2/10
# 49/49 [==============================] - 2190s 45s/step - loss: 0.0329 - acc: 0.9910 - val_loss: 0.0064 - val_acc: 1.0000
#
# Epoch 00002: val_loss improved from 0.22100 to 0.00637, saving model to ../models\resnet_large.h5
# Epoch 3/10
# 10/49 [=====>........................] - ETA: 29:06 - loss: 0.0122 - acc: 0.9937
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9300/3480609126.py in <module>
#       5
#       6 # lets check the time for this too
# ...

# %% [markdown]
# ## Checking the Accuracy and Loss of the Model

# %%
fig, loss_ax = plt.subplots(figsize=(16, 10))
acc_ax = loss_ax.twinx()

loss_ax.plot(history.history['loss'], 'y', label='train loss')
loss_ax.plot(history.history['val_loss'], 'r', label='val loss')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(loc=4, bbox_to_anchor = (1,0.1))

acc_ax.plot(history.history['acc'], 'b', label='train acc')
acc_ax.plot(history.history['val_acc'], 'g', label='val acc')
acc_ax.set_ylabel('accuracy')
acc_ax.legend(loc = 1, bbox_to_anchor = (1, 0.85))

plt.title('Accuracy and Loss Per Epoch', size = 18)
plt.show()

# %% [markdown]
# ## Loading in Models

# %% [markdown]
# **Found pretrained models to use [here](https://keras.io/api/applications/)**

# %%
# Model we just made
resnet = load_model('../models/resnet_large.h5')

# Models trained in Colab
incep = load_model('../models/inception.h5') # 480 x 640
mn = load_model('../models/mobilenet.h5') # 224 x 224
mn_v2 = load_model('../models/mobilenetv2.h5') # 224 x 224
mn_v2_2 = load_model('../models/mobilenetv2_@.h5')

# resnet_small = load_model('../models/resnet_180_240.h5') # 180 x 240 won't load in, same issue as renet large

# %% [markdown]
# ## Evaluating the Model on the testing_set one more time

# %%
rescale = ImageDataGenerator(rescale=1/255)

test_set_normal = rescale.flow_from_directory('../imgs/test/',
                                   target_size=(480, 640),
                                   class_mode='categorical',
                                   batch_size= 1)

test_set_square = rescale.flow_from_directory('../imgs/test/',
                                   target_size=(224, 224),
                                   class_mode='categorical',
                                   batch_size= 1)


val_set_normal = rescale.flow_from_directory('../imgs/collected/test_set_folders/test_set/',
                                   target_size=(480, 640),
                                   class_mode='categorical',
                                   batch_size= 1)
val_set_square = rescale.flow_from_directory('../imgs/collected/test_set_folders/test_set/',
                                   target_size=(224, 224),
                                   class_mode='categorical',
                                   batch_size= 1)
# Out:
# Found 144 images belonging to 6 classes.
# Found 144 images belonging to 6 classes.
# Found 15 images belonging to 6 classes.
# Found 15 images belonging to 6 classes.

# %% [markdown]
# ## Evaluating the Model On new Unseen images

# %%
actions = ['forward', 'play_pause', 'rewind', 'screenshot', 'volume_down', 'volume_up']

files = [f for f in listdir('../imgs/collected/test_set') if isfile(join('../imgs/collected/test_set', f))]

# %% [markdown]
# ### InceptionResNetV2

# %%
resnet.evaluate(test_set_normal)
resnet.evaluate(val_set_normal)
# Out:
# ...
# 15/15 [==============================] - 25s 2s/step - loss: 0.0103 - acc: 1.0000
# [0.01027670968323946, 1.0]

# %%
print('This is for the RESNET model')
print('----------------------------')
for file in files:
    test = cv2.imread(f'../imgs/collected/test_set/{file}')
#     image = cv2.cvtColor(test, cv2.COLOR_RGB2BGR)
#     plt.imshow(image)
#     plt.show()
    t0 = time.time()
    pred_prob = resnet.predict(test.reshape(1, 480, 640, 3)/255.0)
    pred = actions[np.argmax(pred_prob)]
    print(f'{round(time.time() - t0,3)} seconds to run')
    print(f"Picture is: {file.split('_')[0]}\nPrediction is: {pred}")
    print(f'Confidence: {np.max(pred_prob)}')
    print('---'*15)
# Out:
# This is for the RESNET model
# ----------------------------
# 1.673 seconds to run
# Picture is: forward
# Prediction is: forward
# Confidence: 0.9515164494514465
# ---------------------------------------------
# 1.416 seconds to run
# Picture is: forward
# Prediction is: forward
# Confidence: 0.9264510273933411
# ---------------------------------------------
# 1.379 seconds to run
# Picture is: forward
# Prediction is: forward
# Confidence: 0.950688362121582
# ---------------------------------------------
# 1.373 seconds to run
# Picture is: pp
# Prediction is: play_pause
# Confidence: 0.9986024498939514
# ---------------------------------------------
# 1.393 seconds to run
# Picture is: pp
# Prediction is: play_pause
# Confidence: 0.997757613658905
# ---------------------------------------------
# 1.4 seconds to run
# Picture is: pp
# Prediction is: play_pause
# Confidence: 0.9979285001754761
# ---------------------------------------------
# 1.565 seconds to run
# ...

# %% [markdown]
# ### Inception Model

# %%
incep.evaluate(test_set_normal)
incep.evaluate(val_set_normal)
# Out:
# ...
# 15/15 [==============================] - 14s 937ms/step - loss: 4.9357e-04 - acc: 1.0000
# [0.0004935743636451662, 1.0]

# %%
print('This is for the Inception model')
print('-------------------------------')
for file in files:
    test = cv2.imread(f'../imgs/collected/test_set/{file}')
    t0 = time.time()
    pred_prob = incep.predict(test.reshape(1, 480, 640, 3)/255.0)
    pred = actions[np.argmax(pred_prob)]
    print(f'{round(time.time() - t0,3)} seconds to run')
    print(f"Picture is: {file.split('_')[0]}\nPrediction is: {pred}")
    print(f'Confidence: {np.max(pred_prob)}')
    print('---'*15)
# Out:
# This is for the Inception model
# ----------------------------
# 2.028 seconds to run
# Picture is: forward
# Prediction is: forward
# Confidence: 0.9997003078460693
# ---------------------------------------------
# 0.725 seconds to run
# Picture is: forward
# Prediction is: forward
# Confidence: 0.9998468160629272
# ---------------------------------------------
# 0.727 seconds to run
# Picture is: forward
# Prediction is: forward
# Confidence: 0.9997901320457458
# ---------------------------------------------
# 0.726 seconds to run
# Picture is: pp
# Prediction is: play_pause
# Confidence: 0.9999603033065796
# ---------------------------------------------
# 0.754 seconds to run
# Picture is: pp
# Prediction is: play_pause
# Confidence: 0.9998279809951782
# ---------------------------------------------
# 0.763 seconds to run
# Picture is: pp
# Prediction is: play_pause
# Confidence: 0.9999011754989624
# ---------------------------------------------
# 0.774 seconds to run
# ...

# %% [markdown]
# ### MobileNet

# %%
cv = cv2.imread('../imgs/collected/test_set/pp_1.jpg')
cv/255
# Out:
# array([[[0.65490196, 0.67843137, 0.6745098 ],
#         [0.64313725, 0.66666667, 0.6627451 ],
#         [0.6627451 , 0.68235294, 0.67843137],
#         ...,
#         [0.04705882, 0.07058824, 0.05098039],
#         [0.04313725, 0.06666667, 0.04705882],
#         [0.03921569, 0.0627451 , 0.04313725]],
#
#        [[0.64313725, 0.66666667, 0.6627451 ],
#         [0.65490196, 0.67843137, 0.6745098 ],
#         [0.65882353, 0.67843137, 0.6745098 ],
#         ...,
#         [0.04313725, 0.06666667, 0.04705882],
#         [0.05490196, 0.07058824, 0.05098039],
#         [0.04313725, 0.06666667, 0.04705882]],
#
#        [[0.65098039, 0.68235294, 0.67843137],
#         [0.65490196, 0.68627451, 0.68235294],
#         [0.64705882, 0.67058824, 0.66666667],
#         ...,
#         [0.04313725, 0.05882353, 0.03921569],
#         [0.05098039, 0.05490196, 0.03921569],
#         [0.04705882, 0.0627451 , 0.04313725]],
#
#        ...,
#
#        [[0.63921569, 0.61568627, 0.58823529],
# ...

# %%
img = load_img('../imgs/collected/test_set/pp_1.jpg')
img_to_array(img)[...,::-1]/255
# Out:
# array([[[0.654902  , 0.6784314 , 0.6745098 ],
#         [0.6431373 , 0.6666667 , 0.6627451 ],
#         [0.6627451 , 0.68235296, 0.6784314 ],
#         ...,
#         [0.04705882, 0.07058824, 0.05098039],
#         [0.04313726, 0.06666667, 0.04705882],
#         [0.03921569, 0.0627451 , 0.04313726]],
#
#        [[0.6431373 , 0.6666667 , 0.6627451 ],
#         [0.654902  , 0.6784314 , 0.6745098 ],
#         [0.65882355, 0.6784314 , 0.6745098 ],
#         ...,
#         [0.04313726, 0.06666667, 0.04705882],
#         [0.05490196, 0.07058824, 0.05098039],
#         [0.04313726, 0.06666667, 0.04705882]],
#
#        [[0.6509804 , 0.68235296, 0.6784314 ],
#         [0.654902  , 0.6862745 , 0.68235296],
#         [0.64705884, 0.67058825, 0.6666667 ],
#         ...,
#         [0.04313726, 0.05882353, 0.03921569],
#         [0.05098039, 0.05490196, 0.03921569],
#         [0.04705882, 0.0627451 , 0.04313726]],
#
#        ...,
#
#        [[0.6392157 , 0.6156863 , 0.5882353 ],
# ...

# %%
mn.evaluate(test_set_square)
mn.evaluate(val_set_square)
# Out:
# ...
# 15/15 [==============================] - 1s 39ms/step - loss: 0.0031 - acc: 1.0000
# [0.0031312007922679186, 1.0]

# %%
print('This is for the MobileNet model')
print('-------------------------------')
for file in files:
    test = cv2.imread(f'../imgs/collected/test_set/{file}')
    test =  cv2.resize(test, (224,224), interpolation = cv2.INTER_AREA)
    t0 = time.time()
    pred_prob = mn.predict(test.reshape(1, 224, 224, 3)/255)
    pred = actions[np.argmax(pred_prob)]
    print(f'{round(time.time() - t0,3)} seconds to run')
    print(f"Picture is: {file.split('_')[0]}\nPrediction is: {pred}")
    print(f'Confidence: {np.max(pred_prob)}')
    print('---'*15)
# Out:
# This is for the MobileNet model
# -------------------------------
# 0.08 seconds to run
# Picture is: forward
# Prediction is: forward
# Confidence: 0.9995170831680298
# ---------------------------------------------
# 0.068 seconds to run
# Picture is: forward
# Prediction is: forward
# Confidence: 0.9989919066429138
# ---------------------------------------------
# 0.068 seconds to run
# Picture is: forward
# Prediction is: forward
# Confidence: 0.9995664954185486
# ---------------------------------------------
# 0.067 seconds to run
# Picture is: pp
# Prediction is: play_pause
# Confidence: 0.9573161005973816
# ---------------------------------------------
# 0.064 seconds to run
# Picture is: pp
# Prediction is: play_pause
# Confidence: 0.966025710105896
# ---------------------------------------------
# 0.066 seconds to run
# Picture is: pp
# Prediction is: play_pause
# Confidence: 0.9668229222297668
# ---------------------------------------------
# 0.07 seconds to run
# ...

# %% [markdown]
# ### MobileNetV2

# %%
mn_v2_2.evaluate(test_set_square)
mn_v2_2.evaluate(val_set_square)
# Out:
# ...
# 15/15 [==============================] - 1s 42ms/step - loss: 1.0161 - acc: 0.8000
# [1.0160894393920898, 0.800000011920929]

# %%
print('This is for the MobileNetV2 model')
print('---------------------------------')
for file in files:
    test = load_img(f'../imgs/collected/test_set/{file}', target_size=(224, 224))
    t0 = time.time()
    test = (img_to_array(test)[...,::-1]/255).astype(np.float32)
    pred_prob = mn_v2.predict(test.reshape(1,224,224,3))
    pred = actions[np.argmax(pred_prob)]
    print(f'{round(time.time() - t0,3)} seconds to run')
    print(f"Picture is: {file.split('_')[0]}\nPrediction is: {pred}")
    print(f'Confidence: {np.max(pred_prob)}')
    print('---'*15)
# Out:
# This is for the MobileNetV2 model
# ---------------------------------
# 0.547 seconds to run
# Picture is: forward
# Prediction is: forward
# Confidence: 0.9999943971633911
# ---------------------------------------------
# 0.064 seconds to run
# Picture is: forward
# Prediction is: forward
# Confidence: 0.9999923706054688
# ---------------------------------------------
# 0.064 seconds to run
# Picture is: forward
# Prediction is: forward
# Confidence: 0.9999903440475464
# ---------------------------------------------
# 0.063 seconds to run
# Picture is: pp
# Prediction is: play_pause
# Confidence: 0.9987006187438965
# ---------------------------------------------
# 0.077 seconds to run
# Picture is: pp
# Prediction is: play_pause
# Confidence: 0.9975928664207458
# ---------------------------------------------
# 0.065 seconds to run
# Picture is: pp
# Prediction is: play_pause
# Confidence: 0.9984812140464783
# ---------------------------------------------
# 0.067 seconds to run
# ...

# %%
# https://stackoverflow.com/questions/68656751/how-to-speed-up-the-keras-model-predict
# https://github.com/leimao/Frozen-Graph-TensorFlow/tree/master/TensorFlow_v2
import tensorflow as tf
from tensorflow import keras
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2

def wrap_frozen_graph(graph_def, inputs, outputs, print_graph=False):
    def _imports_graph_def():
        tf.compat.v1.import_graph_def(graph_def, name="")

    wrapped_import = tf.compat.v1.wrap_function(_imports_graph_def, [])
    import_graph = wrapped_import.graph

    if print_graph == True:
        print("-" * 50)
        print("Frozen model layers: ")
        layers = [op.name for op in import_graph.get_operations()]
        for layer in layers:
            print(layer)
        print("-" * 50)

    return wrapped_import.prune(
        tf.nest.map_structure(import_graph.as_graph_element, inputs),
        tf.nest.map_structure(import_graph.as_graph_element, outputs))

full_model = tf.function(lambda x: model(x))
full_model = full_model.get_concrete_function(x=(tf.TensorSpec(model.inputs[0].shape, model.inputs[0].dtype)))

# Get frozen ConcreteFunction
# https://github.com/tensorflow/tensorflow/issues/36391#issuecomment-596055100
frozen_func = convert_variables_to_constants_v2(full_model, lower_control_flow=False)
frozen_func.graph.as_graph_def()

layers = [op.name for op in frozen_func.graph.get_operations()]
print("-" * 50)
print("Frozen model layers: ")
for layer in layers:
    print(layer)

print("-" * 50)
print("Frozen model inputs: ")
print(frozen_func.inputs)
print("Frozen model outputs: ")
print(frozen_func.outputs)

# Save frozen graph from frozen ConcreteFunction to hard drive
tf.io.write_graph(graph_or_graph_def=frozen_func.graph,
                    logdir="./frozen_models",
                    name="complex_frozen_graph.pb",
                    as_text=False)

# Load frozen graph using TensorFlow 1.x functions
with tf.io.gfile.GFile("./frozen_models/complex_frozen_graph.pb", "rb") as f:
    graph_def = tf.compat.v1.GraphDef()
    loaded = graph_def.ParseFromString(f.read())
    
    
# Wrap frozen graph to ConcreteFunctions
frozen_func = wrap_frozen_graph(graph_def=graph_def,
                                inputs=["x:0"],
                                outputs=["Identity:0"],
                                print_graph=True)
# Out:
# --------------------------------------------------
# Frozen model layers:
# x
# sequential_2/inception_resnet_v2/conv2d/Conv2D/ReadVariableOp/resource
# sequential_2/inception_resnet_v2/conv2d/Conv2D/ReadVariableOp
# sequential_2/inception_resnet_v2/conv2d/Conv2D
# sequential_2/inception_resnet_v2/batch_normalization/scale
# sequential_2/inception_resnet_v2/batch_normalization/ReadVariableOp/resource
# sequential_2/inception_resnet_v2/batch_normalization/ReadVariableOp
# sequential_2/inception_resnet_v2/batch_normalization/FusedBatchNormV3/ReadVariableOp/resource
# sequential_2/inception_resnet_v2/batch_normalization/FusedBatchNormV3/ReadVariableOp
# sequential_2/inception_resnet_v2/batch_normalization/FusedBatchNormV3/ReadVariableOp_1/resource
# sequential_2/inception_resnet_v2/batch_normalization/FusedBatchNormV3/ReadVariableOp_1
# sequential_2/inception_resnet_v2/batch_normalization/FusedBatchNormV3
# sequential_2/inception_resnet_v2/activation/Relu
# ...

# %%
image = cv2.imread('../imgs/collected/test_set/pp_1.jpg')
frozen_func(x = tf.constant(image.reshape(1, 480, 640, 3)/255, dtype = float))
# Out:
# [<tf.Tensor: shape=(1, 6), dtype=float32, numpy=
#  array([[1.1447367e-05, 9.9860245e-01, 3.1449474e-04, 5.6841591e-04,
#          2.3053339e-04, 2.7269422e-04]], dtype=float32)>]
